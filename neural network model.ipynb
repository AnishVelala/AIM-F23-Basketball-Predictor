# %%
import pandas as pd
import numpy as np
import tensorflow as tf


# Import the dataset
df = pd.read_csv('./data/dataset.csv')
df.head()
# Out:
#    Unnamed: 0  home_last_3_P  home_last_3_OppP  home_last_3_FG  \
# 0           0         112.33            106.33           42.33
# 1           0         112.00            104.33           44.00
# 2           0         125.00            120.00           46.67
# 3           0         119.00            109.67           42.67
# 4           0         117.33            110.33           43.00
#
#    home_last_3_FGA  home_last_3_FG%  home_last_3_3P  home_last_3_3PA  \
# 0            84.67             0.50           11.33            31.33
# 1            94.67             0.47            8.67            29.67
# 2            90.67             0.51           14.67            37.33
# 3            89.33             0.48           15.33            38.33
# 4            87.00             0.49           13.67            38.67
#
#    home_last_3_3P%  home_last_3_FT  ...  away_last_50_DeFG%  \
# 0             0.36           16.33  ...                0.51
# 1             0.29           15.33  ...                0.52
# 2             0.39           17.00  ...                0.56
# 3             0.40           18.33  ...                0.51
# 4             0.35           17.67  ...                0.52
#
#    away_last_50_DTOV%  away_last_50_DDRB%  away_last_50_DFT/FGA  \
# 0               12.67               76.90                  0.18
# 1               11.68               77.64                  0.17
# 2               12.00               78.43                  0.20
# 3               12.66               78.26                  0.20
# 4               12.32               78.22                  0.19
#
#    away_last_50_W  away_last_50_H        Date  Home_Team  Away_Team  \
# 0            41.0            27.0  2022-02-03        ATL        PHO
# 1            32.0            25.0  2022-02-10        ATL        MIL
# 2            20.0            28.0  2022-02-14        ATL        POR
# 3            34.0            26.0  2022-02-24        ATL        GSW
# 4            28.0            25.0  2022-02-27        ATL        DAL
#
#    Home_Team_Won
# 0           True
# 1           True
# 2          False
# 3          False
# 4          False
#
# [5 rows x 233 columns]

# %%
#We want clean the data and split up the input and output
target_column = "Home_Team_Won"
unneeded_columns = ["Date", "Home_Team", "Away_Team"]


#remove first column from dataset
df = df.drop(df.columns[[0]],axis = 1)


#remove unneed_columns. These are columns that are in our dataset, but we don't want to feed into the model
#this is because they are categorical, we're only feeding our model numerical data
clean_df = df.drop(columns=unneeded_columns, axis=1)


# making new data frame with dropped NA values
clean_df = clean_df.dropna(axis=0, how='any')


#get the output rows of the dataset
output_rows = clean_df[target_column]


#remove output rows from the dataset
clean_df = clean_df.drop(columns=target_column, axis=1)


clean_df.head()
# Out:
#    home_last_3_P  home_last_3_OppP  home_last_3_FG  home_last_3_FGA  \
# 0         112.33            106.33           42.33            84.67
# 1         112.00            104.33           44.00            94.67
# 2         125.00            120.00           46.67            90.67
# 3         119.00            109.67           42.67            89.33
# 4         117.33            110.33           43.00            87.00
#
#    home_last_3_FG%  home_last_3_3P  home_last_3_3PA  home_last_3_3P%  \
# 0             0.50           11.33            31.33             0.36
# 1             0.47            8.67            29.67             0.29
# 2             0.51           14.67            37.33             0.39
# 3             0.48           15.33            38.33             0.40
# 4             0.49           13.67            38.67             0.35
#
#    home_last_3_FT  home_last_3_FTA  ...  away_last_50_OeFG%  \
# 0           16.33            22.67  ...                0.54
# 1           15.33            19.00  ...                0.54
# 2           17.00            24.00  ...                0.52
# 3           18.33            23.67  ...                0.55
# 4           17.67            23.00  ...                0.54
#
#    away_last_50_OTOV%  away_last_50_OORB%  away_last_50_OFT/FGA  \
# 0               11.55               22.63                  0.18
# 1               11.64               23.25                  0.19
# 2               11.80               21.96                  0.20
# 3               13.17               23.19                  0.18
# 4               10.83               21.59                  0.19
#
#    away_last_50_DeFG%  away_last_50_DTOV%  away_last_50_DDRB%  \
# 0                0.51               12.67               76.90
# 1                0.52               11.68               77.64
# 2                0.56               12.00               78.43
# 3                0.51               12.66               78.26
# 4                0.52               12.32               78.22
#
#    away_last_50_DFT/FGA  away_last_50_W  away_last_50_H
# 0                  0.18            41.0            27.0
# 1                  0.17            32.0            25.0
# 2                  0.20            20.0            28.0
# 3                  0.20            34.0            26.0
# 4                  0.19            28.0            25.0
#
# [5 rows x 228 columns]

# %%
from sklearn.model_selection import train_test_split

#we cleaned up our data, now we are going to split it and get it ready to feed into the model
X_train, X_test, y_train, y_test = train_test_split(clean_df, output_rows, test_size=0.25, random_state=0)


#now we have our training and testing dataset
print('X_train:',np.shape(X_train))
print('y_train:',np.shape(y_train))
print('X_test:',np.shape(X_test))
print('y_test:',np.shape(y_test))
# Out:
# X_train: (1223, 228)
# y_train: (1223,)
# X_test: (408, 228)
# y_test: (408,)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=228, activation='relu', input_shape=(228,)))
model.add(tf.keras.layers.Dense(228, activation='sigmoid'))

# %%
model.compile(optimizer='adam',  # Use an appropriate optimizer (e.g., 'adam')
              loss='mean_squared_error',  # Use an appropriate loss function
              metrics=['accuracy'])  # Choose evaluation metrics
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 39/39 [==============================] - 0s 912us/step - loss: 0.4780 - accuracy: 0.4015
# Epoch 2/50
# 39/39 [==============================] - 0s 787us/step - loss: 0.4735 - accuracy: 0.4677
# Epoch 3/50
# 39/39 [==============================] - 0s 866us/step - loss: 0.4764 - accuracy: 0.4677
# Epoch 4/50
# 39/39 [==============================] - 0s 906us/step - loss: 0.4762 - accuracy: 0.4677
# Epoch 5/50
# 39/39 [==============================] - 0s 887us/step - loss: 0.4814 - accuracy: 0.4677
# Epoch 6/50
# 39/39 [==============================] - 0s 885us/step - loss: 0.4788 - accuracy: 0.4677
# Epoch 7/50
# 39/39 [==============================] - 0s 924us/step - loss: 0.4788 - accuracy: 0.4677
# Epoch 8/50
# 39/39 [==============================] - 0s 908us/step - loss: 0.4795 - accuracy: 0.4677
# Epoch 9/50
# 39/39 [==============================] - 0s 927us/step - loss: 0.4789 - accuracy: 0.4677
# Epoch 10/50
# 39/39 [==============================] - 0s 845us/step - loss: 0.4789 - accuracy: 0.4677
# Epoch 11/50
# 39/39 [==============================] - 0s 891us/step - loss: 0.4791 - accuracy: 0.4677
# Epoch 12/50
# 39/39 [==============================] - 0s 882us/step - loss: 0.4757 - accuracy: 0.4677
# Epoch 13/50
# 39/39 [==============================] - 0s 908us/step - loss: 0.4747 - accuracy: 0.4677
# Epoch 14/50
# 39/39 [==============================] - 0s 893us/step - loss: 0.4737 - accuracy: 0.4677
# Epoch 15/50
# 39/39 [==============================] - 0s 1ms/step - loss: 0.4693 - accuracy: 0.4677
# Epoch 16/50
# 39/39 [==============================] - 0s 875us/step - loss: 0.4587 - accuracy: 0.4677
# Epoch 17/50
# 39/39 [==============================] - 0s 904us/step - loss: 0.4252 - accuracy: 0.3688
# Epoch 18/50
# 39/39 [==============================] - 0s 976us/step - loss: 0.2530 - accuracy: 0.0000e+00
# Epoch 19/50
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.0000e+00
# Epoch 20/50
# 39/39 [==============================] - 0s 902us/step - loss: 0.2493 - accuracy: 0.0000e+00
# Epoch 21/50
# 39/39 [==============================] - 0s 860us/step - loss: 0.2492 - accuracy: 0.0000e+00
# Epoch 22/50
# 39/39 [==============================] - 0s 921us/step - loss: 0.2491 - accuracy: 0.0000e+00
# Epoch 23/50
# 39/39 [==============================] - 0s 879us/step - loss: 0.2491 - accuracy: 0.0000e+00
# Epoch 24/50
# 39/39 [==============================] - 0s 832us/step - loss: 0.2491 - accuracy: 0.0000e+00
# Epoch 25/50
# 39/39 [==============================] - 0s 874us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 26/50
# 39/39 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 27/50
# 39/39 [==============================] - 0s 891us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 28/50
# 39/39 [==============================] - 0s 854us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 29/50
# 39/39 [==============================] - 0s 826us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 30/50
# 39/39 [==============================] - 0s 813us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 31/50
# 39/39 [==============================] - 0s 833us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 32/50
# 39/39 [==============================] - 0s 836us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 33/50
# 39/39 [==============================] - 0s 846us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 34/50
# 39/39 [==============================] - 0s 912us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 35/50
# 39/39 [==============================] - 0s 973us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 36/50
# 39/39 [==============================] - 0s 933us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 37/50
# 39/39 [==============================] - 0s 902us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 38/50
# 39/39 [==============================] - 0s 865us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 39/50
# 39/39 [==============================] - 0s 855us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 40/50
# 39/39 [==============================] - 0s 826us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 41/50
# 39/39 [==============================] - 0s 876us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 42/50
# 39/39 [==============================] - 0s 826us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 43/50
# 39/39 [==============================] - 0s 796us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 44/50
# 39/39 [==============================] - 0s 806us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 45/50
# 39/39 [==============================] - 0s 846us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 46/50
# 39/39 [==============================] - 0s 841us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 47/50
# 39/39 [==============================] - 0s 799us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 48/50
# 39/39 [==============================] - 0s 916us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 49/50
# 39/39 [==============================] - 0s 907us/step - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 50/50
# 39/39 [==============================] - 0s 1ms/step - loss: 0.2490 - accuracy: 0.0000e+00
